# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import bar_chart_race as bcr

# %%
df = pd.read_csv("owid-covid-data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54554 entries, 0 to 54553
# Data columns (total 52 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            54240 non-null  object
#  1   continent                           53910 non-null  object
#  2   location                            54554 non-null  object
#  3   date                                54554 non-null  object
#  4   total_cases                         53997 non-null  float64
#  5   new_cases                           53807 non-null  float64
#  6   new_cases_smoothed                  52851 non-null  float64
#  7   total_deaths                        45957 non-null  float64
#  8   new_deaths                          45783 non-null  float64
#  9   new_deaths_smoothed                 52851 non-null  float64
#  10  total_cases_per_million             53683 non-null  float64
#  11  new_cases_per_million               53494 non-null  float64
#  12  new_cases_smoothed_per_million      52543 non-null  float64
#  13  total_deaths_per_million            45656 non-null  float64
#  14  new_deaths_per_million              45483 non-null  float64
#  15  new_deaths_smoothed_per_million     52543 non-null  float64
#  16  reproduction_rate                   42503 non-null  float64
#  17  icu_patients                        4820 non-null   float64
#  18  icu_patients_per_million            4820 non-null   float64
#  19  hosp_patients                       5779 non-null   float64
#  20  hosp_patients_per_million           5779 non-null   float64
#  21  weekly_icu_admissions               470 non-null    float64
#  22  weekly_icu_admissions_per_million   470 non-null    float64
#  23  weekly_hosp_admissions              769 non-null    float64
#  24  weekly_hosp_admissions_per_million  769 non-null    float64
#  25  new_tests                           25362 non-null  float64
#  26  total_tests                         25308 non-null  float64
#  27  total_tests_per_thousand            25308 non-null  float64
#  28  new_tests_per_thousand              25362 non-null  float64
#  29  new_tests_smoothed                  28329 non-null  float64
#  30  new_tests_smoothed_per_thousand     28329 non-null  float64
#  31  positive_rate                       26646 non-null  float64
#  32  tests_per_case                      26041 non-null  float64
#  33  tests_units                         29402 non-null  object
#  34  total_vaccinations                  2 non-null      float64
#  35  total_vaccinations_per_hundred      2 non-null      float64
#  36  stringency_index                    48111 non-null  float64
#  37  population                          54240 non-null  float64
#  38  population_density                  53092 non-null  float64
#  39  median_age                          51925 non-null  float64
#  40  aged_65_older                       51319 non-null  float64
#  41  aged_70_older                       51630 non-null  float64
#  42  gdp_per_capita                      51922 non-null  float64
#  43  extreme_poverty                     35545 non-null  float64
#  44  cardiovasc_death_rate               52457 non-null  float64
#  45  diabetes_prevalence                 53070 non-null  float64
#  46  female_smokers                      41479 non-null  float64
#  47  male_smokers                        40912 non-null  float64
#  48  handwashing_facilities              26181 non-null  float64
#  49  hospital_beds_per_thousand          48257 non-null  float64
#  50  life_expectancy                     53962 non-null  float64
#  51  human_development_index             52148 non-null  float64
# dtypes: float64(47), object(5)
# memory usage: 21.6+ MB

# %%
df[['location','total_deaths_per_million','population']][df['date'] == '2020-12-15'].sort_values(by=['population'], ascending=True).head(20).location
# Out:
# 52818                             Vatican
# 41867                          San Marino
# 28744                       Liechtenstein
# 32592                              Monaco
# 40988               Saint Kitts and Nevis
# 31113                    Marshall Islands
# 14133                            Dominica
# 1164                              Andorra
# 1715                  Antigua and Barbuda
# 43278                          Seychelles
# 41544    Saint Vincent and the Grenadines
# 19688                             Grenada
# 41266                         Saint Lucia
# 41573                               Samoa
# 42122               Sao Tome and Principe
# 4375                             Barbados
# 52532                             Vanuatu
# 22032                             Iceland
# 3514                              Bahamas
# 5254                               Belize
# Name: location, dtype: object

# %%
df['total_deaths_per_million'] = df['total_deaths_per_million'].replace(np.NaN,0)

# %%
df['total_deaths_per_million'] = df['total_deaths_per_million'].fillna(0).astype(np.int64)

# %%
df.drop(df[df['population'] < 1000000].index, inplace=True)

# %%
df_pivoted = df[df['continent'] == 'South America'].pivot(index='date', columns='location', values='total_deaths_per_million')
#df_pivoted = df.pivot(index='date', columns='location', values='total_deaths_per_million')

# %%
df_pivoted = df_pivoted.fillna(0).astype(np.int64)

# %%
df_pivoted = df_pivoted.replace(np.NaN,0)

# %%
df_pivoted.head(15)
# Out:
# location    Argentina  Bolivia  Brazil  Chile  Colombia  Ecuador  Paraguay  \
# date
# 2020-01-01          0        0       0      0         0        0         0
# 2020-02-03          0        0       0      0         0        0         0
# 2020-02-04          0        0       0      0         0        0         0
# 2020-02-05          0        0       0      0         0        0         0
# 2020-02-06          0        0       0      0         0        0         0
# 2020-02-07          0        0       0      0         0        0         0
# 2020-02-08          0        0       0      0         0        0         0
# 2020-02-09          0        0       0      0         0        0         0
# 2020-02-10          0        0       0      0         0        0         0
# 2020-02-11          0        0       0      0         0        0         0
# 2020-02-12          0        0       0      0         0        0         0
# 2020-02-13          0        0       0      0         0        0         0
# 2020-02-14          0        0       0      0         0        0         0
# 2020-02-15          0        0       0      0         0        0         0
# 2020-02-16          0        0       0      0         0        0         0
#
# location    Peru  Uruguay  Venezuela
# date
# 2020-01-01     0        0          0
# 2020-02-03     0        0          0
# 2020-02-04     0        0          0
# 2020-02-05     0        0          0
# 2020-02-06     0        0          0
# 2020-02-07     0        0          0
# 2020-02-08     0        0          0
# 2020-02-09     0        0          0
# 2020-02-10     0        0          0
# 2020-02-11     0        0          0
# 2020-02-12     0        0          0
# 2020-02-13     0        0          0
# 2020-02-14     0        0          0
# 2020-02-15     0        0          0
# 2020-02-16     0        0          0

# %%
df_pivoted.index[:130]
# Out:
# Index(['2020-01-01', '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#        '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10', '2020-02-11',
#        ...
#        '2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04', '2020-06-05',
#        '2020-06-06', '2020-06-07', '2020-06-08', '2020-06-09', '2020-06-10'],
#       dtype='object', name='date', length=130)

# %%
df_pivoted.drop(df_pivoted.index[:130],inplace=True) #onde o Brazil someça a aparecer

# %%
clrs = ['green' if (x == 'Brazil') else 'grey' for x in df.location.unique()]
clrs = ['green' if (x == 'Brazil') else 'grey' for x in df[df['continent'] == 'South America'].location.unique()]

# %%
def summary(values, ranks):
    total_deaths = int(round(values.sum(), -2))
    s = f'Total Deaths - {total_deaths:,.0f}'
    return {'x': .99, 'y': .05, 's': s, 'ha': 'right', 'size': 8}

# %%
def rank(values, ranks):
    top2 = values.nlargest(2)
    leader = top2.index[0]
    lead = top2.iloc[0] - top2.iloc[1]
    s = f'{leader} by {lead:.0f}'
    return {'x': .99, 'y': .05, 's': s, 'ha': 'right', 'size': 8}

# %%
df[(df['location'] == 'Brazil') & (df['date'] == '2020-08-01')].head()
# Out:
#      iso_code      continent location        date  total_cases  new_cases  \
# 6805      BRA  South America   Brazil  2020-08-01    2707877.0    45392.0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 6805           44766.286       93563.0      1088.0             1016.286  ...
#
#       gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 6805       14103.452              3.4                177.961
#
#       diabetes_prevalence  female_smokers  male_smokers  \
# 6805                 8.11            10.1          17.9
#
#       handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 6805                     NaN                         2.2            75.88
#
#       human_development_index
# 6805                    0.759
#
# [1 rows x 52 columns]

# %%
bcr.bar_chart_race(df=df_pivoted, 
                   filename=None, 
                   n_bars=20,
                   cmap=clrs,
                   bar_size=.90,
                   steps_per_period=20, 
                   period_length=200,
                   period_fmt='Season {x:,.0}',
                   period_summary_func=rank,
                   title='COVID-19 - Óbtios por milhões de habitantes')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\ProgramData\Anaconda3\envs\data-analytics\lib\site-packages\bar_chart_race\_make_chart.py in make_animation(self)
#     427             if self.html:
# --> 428                 ret_val = anim.to_html5_video()
#     429                 try:
#
# D:\ProgramData\Anaconda3\envs\data-analytics\lib\site-packages\matplotlib\animation.py in to_html5_video(self, embed_limit)
#    1329                                 fps=1000. / self._interval)
# -> 1330                 self.save(str(path), writer=writer)
#    1331                 # Now open and base64 encode.
#
# D:\ProgramData\Anaconda3\envs\data-analytics\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1138                     # Clear the initial frame
# -> 1139                     anim._init_draw()
#    1140                 frame_number = 0
#
# D:\ProgramData\Anaconda3\envs\data-analytics\lib\site-packages\matplotlib\animation.py in _init_draw(self)
#    1734         else:
# -> 1735             self._drawn_artists = self._init_func()
#    1736             if self._blit:
#
# D:\ProgramData\Anaconda3\envs\data-analytics\lib\site-packages\bar_chart_race\_make_chart.py in init_func()
#     419         def init_func():
# --> 420             self.plot_bars(0)
#     421
#
# D:\ProgramData\Anaconda3\envs\data-analytics\lib\site-packages\bar_chart_race\_make_chart.py in plot_bars(self, i)
#     346                 else:
# --> 347                     s = self.period_fmt.format(x=idx_val)
#     348             else:
#
# ValueError: Cannot specify ',' with 's'.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-254-e6d71557a696> in <module>
#       8                    period_fmt='Season {x:,.0}',
#       9                    period_summary_func=rank,
# ---> 10                    title='COVID-19 - Óbtios por milhões de habitantes')
#
# D:\ProgramData\Anaconda3\envs\data-analytics\lib\site-packages\bar_chart_race\_make_chart.py in bar_chart_race(df, filename, orientation, sort, n_bars, fixed_order, fixed_max, steps_per_period, period_length, interpolate_period, label_bars, bar_size, period_label, period_fmt, period_summary_func, perpendicular_bar_func, figsize, cmap, title, title_size, bar_label_size, tick_label_size, shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
#     781                         figsize, cmap, title, title_size, bar_label_size, tick_label_size,
#     782                         shared_fontdict, scale, writer, fig, dpi, bar_kwargs, filter_column_colors)
# --> 783     return bcr.make_animation()
#     784
#     785 def load_dataset(name='covid19'):
#
# D:\ProgramData\Anaconda3\envs\data-analytics\lib\site-packages\bar_chart_race\_make_chart.py in make_animation(self)
#     444             else:
#     445                 message = str(e)
# --> 446             raise Exception(message)
#     447         finally:
#     448             plt.rcParams = self.orig_rcParams
#
# Exception: You do not have ffmpeg installed on your machine. Download
#                             ffmpeg from here: https://www.ffmpeg.org/download.html.
#
#                             Matplotlib's original error message below:
#
#                             Cannot specify ',' with 's'.
